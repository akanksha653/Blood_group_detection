# %% [markdown]
# <a href="https://colab.research.google.com/github/akanksha653/Blood_group_detection/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/krishna111809/fingerprint-based-blood-group-detection.git
# Out:
# fatal: destination path 'fingerprint-based-blood-group-detection' already exists and is not an empty directory.

# %%
data= '/content/fingerprint-based-blood-group-detection/code/Alexnet/Alexnet.ipynb'
read=pd.read_excel(data)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_703/483605893.py in <cell line: 0>()
#       1 data= '/content/fingerprint-based-blood-group-detection/code/Alexnet/Alexnet.ipynb'
# ----> 2 read=pd.read_excel(data)
#
# /usr/local/lib/python3.12/dist-packages/pandas/io/excel/_base.py in read_excel(io, sheet_name, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, parse_dates, date_parser, date_format, thousands, decimal, comment, skipfooter, storage_options, dtype_backend, engine_kwargs)
#     493     if not isinstance(io, ExcelFile):
#     494         should_close = True
# --> 495         io = ExcelFile(
#     496             io,
#     497             storage_options=storage_options,
#
# ...

# %%
# !ls
# Out:
# fingerprint-based-blood-group-detection  sample_data

# %%
# %cd fingerprint-based-blood-group-detection
# Out:
# /content/fingerprint-based-blood-group-detection

# %%
# !ls
# Out:
#  code	   graphs   'performance metrix'   requirements.txt   test
#  dataset   LICENSE   README.md		  'sample dataset'
